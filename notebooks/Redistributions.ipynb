# %% [markdown]
# # Calculate Seat 2pp vote shares following redistribution
#
# The AEC provides two lots of TPP data:
# 1. TPP votes that can be attributed to individual polling places; and
# 2. TPP votes that can only be attributed to an electorate (eg. postal votes)
#
# The idea here is to map all polling places to their new electorates, post redistribution;
# and in the process, up-weight those votes to attribute any electorate-wide votes.

# %% [markdown]
# ## Python set-up

# %%
import shapely
import shapefile
import pandas as pd

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Data acquisition

# %% [markdown]
# ### Shapefiles for new divisions (post redistribution)

# %%
def get_shapefiles() -> tuple[dict[str, list[str]], dict[str, list[shapely.geometry.Polygon]]]:
    """Integogate the shape files for the newly created divisions.
    Return a tuple:
    - a distionary with state names as keys, and a list of seat names as values, and
    - a dictionary with seat names as keys, and a list of polygons as values.
    """ 
    
    redists = {
        "NSW": r"../redistributions/input-data-2022/NSW-october-2024-ESRI.zip",
        "VIC": r"../redistributions/input-data-2022/VIC-october-2024-ESRI.zip",
        "WA": r"../redistributions/input-data-2022/WA-september-2024-ESRI.zip",
        # NT - redistribution process incomplete
    }

    shapes = {
        state: shapefile.Reader(filename) for state, filename in redists.items()
    }

    new_seats: dict[str, list[str]] = {} # state -> list of seat names
    polygons_for_seat: dict[str, list[shapely.geometry.Polygon]] = {}  # seat name -> list of polygons
    for state, shape in shapes.items():
        seats_in_state = []
        for rec in shape.iterShapeRecords():
            seat_polygon_list = []
            new_seat_name = rec.record['Elect_div']
            seats_in_state.append(new_seat_name)
            shape = rec.shape
            parts = shape.parts  # each part is a separate polygon
            for p in parts:
                points = (
                    shape.points[p:parts[parts.index(p)+1]] 
                    if parts.index(p) < len(parts)-1 
                    else shape.points[p:]
                )
                assert points[0] == points[-1], f"First and last points mismatch: {(points[0], points[-1])}"
                polygon = shapely.geometry.Polygon(points)
                seat_polygon_list.append(polygon)
            polygons_for_seat[new_seat_name] = seat_polygon_list
        new_seats[state] = seats_in_state

    return new_seats, polygons_for_seat

state_seats, seat_polygons = get_shapefiles()

# check the polygon counts for each seat
if False:
    for state, seats in state_seats.items():
        for seat in seats:
            print(state, seat, len(seat_polygons[seat]))

# %% [markdown]
# ### 2022 Polling place data

# %%
REMOVE_PPVC = True # remove the PPVCs from the polling places data

def get_polling_places() -> pd.DataFrame:
    """Get the polling places data for the 2022 redistribution."""
    
    pp = pd.read_csv(
        "../redistributions/input-data-2022/" +
        "GeneralPollingPlacesDownload-27966.csv",
        skiprows=1, header=0, index_col="PollingPlaceID"
    )
    assert pp.index.is_unique
    assert pp.index.isna().sum() == 0

    # remove the data for the AEC National EAV Centres - this
    # is all geo-coded to Canberra, so we cannot use it for locations. 
    pp = pp[~((pp["PremisesNm"] == "AEC National EAV Centre") 
              | (pp["PremisesNm"] == "AEC National EAV2 Centre"))]

    # remove pre-poll voting centres
    if REMOVE_PPVC:
        pp = pp[~pp["PollingPlaceNm"].str.contains("PPVC", case=True)] 

    # remove the data where we do not have Lat/Lon coordinates 
    # (eg. hospital teams and multiple remote sites)
    pp = pp[pp["Longitude"].notna()]
    assert pp["Latitude"].notna().all()

    return pp


polling_places = get_polling_places()

# check an example polling place
display(polling_places.loc[polling_places.PollingPlaceNm.str.contains("Narooma")])
# Out:
#                State  DivisionID   DivisionNm  PollingPlaceTypeID  \
# PollingPlaceID
# 710              NSW         117  Eden-Monaro                   1
#
#                PollingPlaceNm                        PremisesNm  \
# PollingPlaceID
# 710                   Narooma  Narooma Sport and Leisure Centre
#
#                 PremisesAddress1 PremisesAddress2 PremisesAddress3  \
# PollingPlaceID
# 710             100 Bluewater Dr              NaN              NaN
#
#                PremisesSuburb PremisesStateAb  PremisesPostCode   Latitude  \
# PollingPlaceID
# 710                   NAROOMA             NSW            2546.0 -36.215989
#
#                  Longitude
# PollingPlaceID
# 710             150.129379

# %% [markdown]
# ### Identify a new (post redistribution) electorate for a polling_place

# %%
def find_electorate(polling_place: int) -> str | None:
    """Find the electorate for a polling place."""
    
    if polling_place not in polling_places.index:
        print(f"Polling place {polling_place} not found.")
        return None
    
    state = polling_places.loc[polling_place, "State"]
    if state not in state_seats:
        print(f"State {state} not found.")
        return None
    
    lat = polling_places.loc[polling_place, "Latitude"]
    lon = polling_places.loc[polling_place, "Longitude"]
    point = shapely.geometry.Point(lon, lat)

    for seat in state_seats[state]:
        for polygon in seat_polygons[seat]:
            if point.within(polygon) :
               return seat

    print(f"Polling place {polling_place} not found in any seat.")
    return None


# check that this code works
print(find_electorate(710))  # Narooma NSW should work
print(find_electorate(6913)) # Ceduna SA should fail
# Out:
# Eden-monaro
# State SA not found.
# None

# %% [markdown]
# ### 2022 TPP totals by division

# %%
KEY_COLS = [
    "DivisionNm", # should be the first column
    "Liberal/National Coalition Votes", 
    "Australian Labor Party Votes", # Labor should be the last column
]

def get_ttp_seat_totals() -> pd.DataFrame:
    """Get the TPP raw seat totals for the 2022 election.
    Seat totals include votes where we dont have
    a polling booth as a proxy for the voter's address/location
    (eg. postal voting, overseas voting, etc)."""
    
    tpp = pd.read_csv(
        "../redistributions/input-data-2022/" +
        "HouseTppByDivisionDownload-27966.csv",
        skiprows=1, header=0, index_col="DivisionNm"
    )[KEY_COLS[1:] + ["StateAb"]]
    assert tpp.index.is_unique
    assert tpp.index.isna().sum() == 0

    return tpp


tpp_seat_total = get_ttp_seat_totals()

# %% [markdown]
# ### 2022 TPP totals by polling place (ie. booth attributable)

# %%
def get_tpp_by_polling_place(pp: pd.DataFrame) -> pd.DataFrame:
    """Get the TPP by polling place for the 2022 election.
    Return the vote totals by polling place."""
    
    # check that we have Lat/Lon coordinates for all polling places
    assert pp.Latitude.notna().all() and pp.Longitude.notna().all()

    # read the AEC TPP data
    tpp = pd.read_csv(
        "../redistributions/input-data-2022/" +
        "HouseTppByPollingPlaceDownload-27966.csv",
        skiprows=1, header=0, index_col="PollingPlaceID",
    )
    assert tpp.index.is_unique
    
    # remove places we cannot map to Lat/Lon 
    # coordinates via a PollingPlaceID
    tpp = tpp[tpp.index.isin(pp.index)]

    return tpp

booth_tpp_by_place = get_tpp_by_polling_place(polling_places)

# %%
def aggregate_places_to_seats(tpp: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """Aggregate the TPP by polling place to TPP by seat.
    Return a tuple:
    - a dataframe of total TPP booth vote by seat
    - a dataframe of individual booth vote adjusted for unmappable data."""

    tpp_copy = tpp.copy()
    
    # We still have a few locatons in redistributed states that don't map to locations cleanly
    # For the most part these are cross boarder polling places
    # so we need to filter these out
    potential_removal = []
    for state in state_seats.keys():
        state_places = polling_places[polling_places.State == state]
        for place in state_places.index:
            f = find_electorate(place)
            if not f:
                potential_removal.append(place)    

    for p in potential_removal:
        if p in tpp_copy.index:
            print(f"Removing polling place {p}: {polling_places.loc[p, "PollingPlaceNm"]} from the data.")
            tpp_copy.drop(p, inplace=True)

    booth_tpp = tpp_copy[KEY_COLS[1:] + ["DivisionNm"]].groupby("DivisionNm").sum()

    return booth_tpp, tpp_copy

booth_tpp_by_seat, adj_booth_tpp_by_place = aggregate_places_to_seats(booth_tpp_by_place)

# check the data
#display(booth_tpp_by_seat)
#display(adj_booth_tpp_by_place.head())
# Out:
# Polling place 83845 not found in any seat.
# Polling place 2887 not found in any seat.
# Removing polling place 83845: Darlinghurst South from the data.
# Removing polling place 2887: Surry Hills from the data.

# %% [markdown]
# ## Data Manipulation

# %%
def calculate_up_weights(
    tpp_seat_total: pd.DataFrame, tpp_place_totals: pd.DataFrame
) -> pd.DataFrame:
    """Calculate the up-weights that will be applied
    to the local polling place data to bring vote 
    totals in line with the divisional totals."""

    weights: list[dict] = []
    for division in tpp_seat_total.index:
        state = tpp_seat_total.loc[division, "StateAb"]
        u = {"State": state}
        for party in KEY_COLS[1:]:
            u[party] = (
                tpp_seat_total.loc[division, party] 
                / tpp_place_totals.loc[division, party]
            )
        u_frame = pd.DataFrame(u, index=[division])
        weights.append(u_frame)
    all_weights = pd.concat(weights)
    return all_weights


up_weights = calculate_up_weights(tpp_seat_total, booth_tpp_by_seat)
#display(up_weights)

# %%
def redistrubute() -> pd.DataFrame:
    """Redistribute the TPP vote totals by polling place
    to the new electoral divisions.  Only in respect of the
    new divisions created by the post-2022 redistributions.
    Returns a DataFrame of the redistributed vote totals."""  

    new_distro = adj_booth_tpp_by_place.copy()
    new_distro["New Division"] = None
    new_distro[KEY_COLS[1:]] = new_distro[KEY_COLS[1:]].astype(float)  # convert to float

    # allocate polling places to new divisions
    state_map = {}
    for state in state_seats:
        places = adj_booth_tpp_by_place[adj_booth_tpp_by_place.StateAb == state]
        for place in places.index:
            old_electorate = places.loc[place, "DivisionNm"]
            electorate = find_electorate(place)
            if electorate:
                state_map[electorate] = state
                new_distro.loc[place, "New Division"] = electorate
                for party in KEY_COLS[1:]:
                    new_distro.loc[place, party] *= up_weights.loc[old_electorate, party]
            else:
                # should not happen - if it does - some code is wrong somewhere above
                print(f"--SHIT-- Polling place {place} not found in any seat.")

    # calculate the redistribution
    new_distro = new_distro[new_distro["New Division"].notna()]
    redistributed = new_distro[KEY_COLS[1:] + ["New Division"]].groupby("New Division").sum()
    redistributed["State"] = redistributed.index.map(state_map)
    return redistributed


redistribution = redistrubute()
display(redistribution.head())
# Out:
#               Liberal/National Coalition Votes  Australian Labor Party Votes  \
# New Division
# Aston                             57705.474508                  52360.058921
# Ballarat                          35730.000000                  60770.000000
# Banks                             51547.334338                  44213.468810
# Barton                            37671.256145                  60711.283207
# Bendigo                           40351.464827                  63192.537684
#
#              State
# New Division
# Aston          VIC
# Ballarat       VIC
# Banks          NSW
# Barton         NSW
# Bendigo        VIC

# %% [markdown]
# ## Construct a TPP pendulum

# %%
COL_NAME = "Labor TPP"


def calculate_labor_tpp(frame: pd.DataFrame) -> pd.DataFrame:
    """Calculate the TPP for the Labor party."""
    
    series = (
        frame[KEY_COLS[-1]] / frame[KEY_COLS[1:]].sum(axis=1)
    ).round(4) * 100 # per cent
    series.name = COL_NAME
    return pd.DataFrame(series)

# %%
def get_pendulum():
    """Calculate the pendulum for the 2022 election."""
    
    projected_tpp = []
    APPROX = "Approximated"

    for state in sorted(tpp_seat_total["StateAb"].unique()):

        if state in state_seats:
            # The redistribution case
            state_data = redistribution[redistribution["State"] == state]
            state_labor_tpp = calculate_labor_tpp(state_data)
            state_labor_tpp[APPROX] = True

        else:
            # the no redistribution case - use existing divisional data from AEC
            state_data = tpp_seat_total[tpp_seat_total["StateAb"] == state]
            state_labor_tpp = calculate_labor_tpp(state_data)
            state_labor_tpp[APPROX] = False

        # collate
        state_labor_tpp[COL_NAME] = state_labor_tpp[COL_NAME]
        state_labor_tpp["State"] = state
        projected_tpp.append(state_labor_tpp)

    # publish
    fix_seats = {
        "Mcmahon": "McMahon", 
        "Eden-monaro": "Eden-Monaro", 
        "Mcewen": "McEwen", 
        "Mcpherson": "McPherson",
        "O'connor": "O'Connor",
    }
    nat_labor_tpp = pd.concat(projected_tpp)
    nat_labor_tpp = nat_labor_tpp.rename(index=fix_seats)
    comparable = nat_labor_tpp.index[nat_labor_tpp.index.isin(tpp_seat_total.index)]
    previously = calculate_labor_tpp(tpp_seat_total.loc[comparable])
    nat_labor_tpp["Pre-redistribution TPP"] = previously
    nat_labor_tpp["Change in Labor's TPP"] = nat_labor_tpp[COL_NAME] - nat_labor_tpp["Pre-redistribution TPP"] 
    nat_labor_tpp = nat_labor_tpp.sort_values(COL_NAME)

    return nat_labor_tpp


pendulum = get_pendulum()
display(len(pendulum))
display(pendulum)
# Out:
# 150
#                  Labor TPP  Approximated State  Pre-redistribution TPP  \
# Maranoa              27.88         False   QLD                   27.88
# Gippsland            29.43          True   VIC                   29.43
# Mallee               31.01          True   VIC                   31.01
# Parkes               32.18          True   NSW                   32.16
# Barker               33.38         False    SA                   33.38
# Farrer               33.65          True   NSW                   33.65
# Nicholls             33.83          True   VIC                   32.85
# New England          34.13          True   NSW                   33.57
# Calare               34.55          True   NSW                   34.55
# Groom                35.83         False   QLD                   35.83
# Lyne                 36.20          True   NSW                   36.20
# Herbert              38.23         False   QLD                   38.23
# Cook                 38.49          True   NSW                   37.56
# Wide Bay             38.66         False   QLD                   38.66
# Moncrieff            38.81         False   QLD                   38.81
# Wright               39.11         False   QLD                   39.11
# Page                 39.32          True   NSW                   39.26
# Fadden               39.37         False   QLD                   39.37
# Dawson               39.58         False   QLD                   39.58
# Riverina             39.83          True   NSW                   35.15
# Kennedy              39.84         False   QLD                   39.84
# Hinkler              39.93         False   QLD                   39.93
# Grey                 39.93         False    SA                   39.93
# Mitchell             40.01          True   NSW                   39.31
# Cowper               40.50          True   NSW                   40.53
# McPherson            40.66         False   QLD                   40.66
# Fairfax              41.05         False   QLD                   41.05
# Wannon               41.32          True   VIC                   40.93
# Fisher               41.33         False   QLD                   41.33
# La Trobe             41.71          True   VIC                   41.31
# Braddon              41.97         False   TAS                   41.97
# Hume                 42.07          True   NSW                   42.28
# Mackellar            42.15          True   NSW                   41.40
# Berowra              42.63          True   NSW                   40.23
# O'Connor             43.34          True    WA                   43.03
# Flinders             43.37          True   VIC                   43.30
# Capricornia          43.41         False   QLD                   43.41
# Bradfield            43.60          True   NSW                   43.45
# Lindsay              44.02          True   NSW                   43.66
# Curtin               44.41          True    WA                   44.40
# Bowman               44.49         False   QLD                   44.49
# Indi                 44.74          True   VIC                   44.74
# Kooyong              44.96          True   VIC                   45.82
# Durack               44.99          True    WA                   45.73
# Petrie               45.56         False   QLD                   45.56
# Forde                45.77         False   QLD                   45.77
# Forrest              45.97          True    WA                   45.71
# Hughes               46.09          True   NSW                   42.99
# Banks                46.17          True   NSW                   46.80
# Flynn                46.18         False   QLD                   46.18
# Leichhardt           46.56         False   QLD                   46.56
# Bonner               46.59         False   QLD                   46.59
# Goldstein            46.76          True   VIC                   45.20
# Longman              46.92         False   QLD                   46.92
# Monash               47.10          True   VIC                   47.10
# Aston                47.57          True   VIC                   47.19
# Wentworth            48.28          True   NSW                   44.08
# Dickson              48.30         False   QLD                   48.30
# Casey                48.32          True   VIC                   48.52
# Bass                 48.57         False   TAS                   48.57
# Canning              48.97          True    WA                   46.41
# Moore                49.16          True    WA                   49.34
# Sturt                49.55         False    SA                   49.55
# Warringah            49.59          True   NSW                   48.57
# Bennelong            49.67          True   NSW                   50.98
# Deakin               50.01          True   VIC                   49.81
# Gilmore              50.16          True   NSW                   50.17
# Menzies              50.82          True   VIC                   49.32
# Lyons                50.92         False   TAS                   50.92
# Lingiari             50.95         False    NT                   50.95
# Mayo                 51.59         False    SA                   51.59
# Robertson            51.97          True   NSW                   52.26
# Bullwinkel           52.33          True    WA                     NaN
# Ryan                 52.42         False   QLD                   52.42
# Paterson             52.68          True   NSW                   53.31
# Tangney              52.90          True    WA                   52.38
# Chisholm             53.06          True   VIC                   56.41
# Boothby              53.28         False    SA                   53.28
# Parramatta           53.54          True   NSW                   54.57
# McEwen               53.54          True   VIC                   53.28
# Brisbane             54.40         False   QLD                   54.40
# Hunter               54.72          True   NSW                   54.03
# Werriwa              55.06          True   NSW                   55.82
# Reid                 55.14          True   NSW                   55.19
# Blair                55.23         False   QLD                   55.23
# Bruce                55.43          True   VIC                   56.59
# Shortland            55.98          True   NSW                   55.82
# Fowler               56.04          True   NSW                   55.72
# Macquarie            56.18          True   NSW                   57.77
# Holt                 56.72          True   VIC                   57.12
# Dobell               56.86          True   NSW                   56.52
# Eden-Monaro          57.30          True   NSW                   58.20
# Hawke                57.61          True   VIC                   57.63
# Dunkley              57.69          True   VIC                   56.27
# Whitlam              57.94          True   NSW                   60.07
# Greenway             58.06          True   NSW                   61.53
# Corangamite          58.17          True   VIC                   57.60
# Richmond             58.23          True   NSW                   58.23
# Hindmarsh            58.95         False    SA                   58.95
# Pearce               59.07          True    WA                   59.04
# Moreton              59.09         False   QLD                   59.09
# Rankin               59.09         False   QLD                   59.09
# Solomon              59.37         False    NT                   59.37
# Cowan                59.39          True    WA                   60.82
# Isaacs               59.45          True   VIC                   56.85
# Swan                 59.81          True    WA                   58.77
# Gorton               59.93          True   VIC                   59.97
# Macarthur            60.36          True   NSW                   58.53
# Gellibrand           60.51          True   VIC                   61.54
# Lilley               60.54         False   QLD                   60.54
# McMahon              60.67          True   NSW                   59.49
# Makin                60.80         False    SA                   60.80
# Bendigo              61.03          True   VIC                   62.11
# Hasluck              61.04          True    WA                   56.00
# Griffith             61.07         False   QLD                   61.07
# Oxley                61.59         False   QLD                   61.59
# Barton               61.71          True   NSW                   65.54
# Adelaide             61.91         False    SA                   61.91
# Jagajaga             62.20          True   VIC                   62.35
# Hotham               62.32          True   VIC                   64.25
# Corio                62.33          True   VIC                   62.84
# Maribyrnong          62.37          True   VIC                   62.45
# Kingsford Smith      62.46          True   NSW                   64.50
# Calwell              62.62          True   VIC                   62.39
# Lalor                62.78          True   VIC                   62.82
# Spence               62.90         False    SA                   62.90
# Bean                 62.95         False   ACT                   62.95
# Ballarat             62.97          True   VIC                   62.97
# Burt                 63.26          True    WA                   65.21
# Macnamara            63.40          True   VIC                   62.25
# Franklin             63.70         False   TAS                   63.70
# Chifley              63.88          True   NSW                   63.47
# Perth                64.30          True    WA                   64.80
# Blaxland             64.45          True   NSW                   64.94
# Cunningham           65.40          True   NSW                   64.70
# Scullin              65.51          True   VIC                   65.58
# Fenner               65.69         False   ACT                   65.69
# Watson               65.72          True   NSW                   65.10
# Kingston             66.35         False    SA                   66.35
# Fraser               66.86          True   VIC                   66.50
# Fremantle            66.91          True    WA                   66.89
# Clark                67.24         False   TAS                   67.24
# Brand                67.39          True    WA                   66.71
# Newcastle            67.81          True   NSW                   67.98
# Melbourne            71.86          True   VIC                   77.91
# Canberra             72.46         False   ACT                   72.46
# Sydney               75.28          True   NSW                   75.57
# Cooper               76.04          True   VIC                   75.46
# Grayndler            77.36          True   NSW                   78.85
# Wills                78.36          True   VIC                   75.77
#
#                  Change in Labor's TPP
# Maranoa                           0.00
# Gippsland                         0.00
# Mallee                            0.00
# Parkes                            0.02
# Barker                            0.00
# Farrer                            0.00
# Nicholls                          0.98
# New England                       0.56
# Calare                            0.00
# Groom                             0.00
# Lyne                              0.00
# Herbert                           0.00
# Cook                              0.93
# Wide Bay                          0.00
# Moncrieff                         0.00
# Wright                            0.00
# Page                              0.06
# Fadden                            0.00
# Dawson                            0.00
# Riverina                          4.68
# Kennedy                           0.00
# Hinkler                           0.00
# Grey                              0.00
# Mitchell                          0.70
# Cowper                           -0.03
# McPherson                         0.00
# Fairfax                           0.00
# Wannon                            0.39
# Fisher                            0.00
# La Trobe                          0.40
# Braddon                           0.00
# Hume                             -0.21
# Mackellar                         0.75
# Berowra                           2.40
# O'Connor                          0.31
# Flinders                          0.07
# Capricornia                       0.00
# Bradfield                         0.15
# Lindsay                           0.36
# Curtin                            0.01
# Bowman                            0.00
# Indi                              0.00
# Kooyong                          -0.86
# Durack                           -0.74
# Petrie                            0.00
# Forde                             0.00
# Forrest                           0.26
# Hughes                            3.10
# Banks                            -0.63
# Flynn                             0.00
# Leichhardt                        0.00
# Bonner                            0.00
# Goldstein                         1.56
# Longman                           0.00
# Monash                            0.00
# Aston                             0.38
# Wentworth                         4.20
# Dickson                           0.00
# Casey                            -0.20
# Bass                              0.00
# Canning                           2.56
# Moore                            -0.18
# Sturt                             0.00
# Warringah                         1.02
# Bennelong                        -1.31
# Deakin                            0.20
# Gilmore                          -0.01
# Menzies                           1.50
# Lyons                             0.00
# Lingiari                          0.00
# Mayo                              0.00
# Robertson                        -0.29
# Bullwinkel                         NaN
# Ryan                              0.00
# Paterson                         -0.63
# Tangney                           0.52
# Chisholm                         -3.35
# Boothby                           0.00
# Parramatta                       -1.03
# McEwen                            0.26
# Brisbane                          0.00
# Hunter                            0.69
# Werriwa                          -0.76
# Reid                             -0.05
# Blair                             0.00
# Bruce                            -1.16
# Shortland                         0.16
# Fowler                            0.32
# Macquarie                        -1.59
# Holt                             -0.40
# Dobell                            0.34
# Eden-Monaro                      -0.90
# Hawke                            -0.02
# Dunkley                           1.42
# Whitlam                          -2.13
# Greenway                         -3.47
# Corangamite                       0.57
# Richmond                          0.00
# Hindmarsh                         0.00
# Pearce                            0.03
# Moreton                           0.00
# Rankin                            0.00
# Solomon                           0.00
# Cowan                            -1.43
# Isaacs                            2.60
# Swan                              1.04
# Gorton                           -0.04
# Macarthur                         1.83
# Gellibrand                       -1.03
# Lilley                            0.00
# McMahon                           1.18
# Makin                             0.00
# Bendigo                          -1.08
# Hasluck                           5.04
# Griffith                          0.00
# Oxley                             0.00
# Barton                           -3.83
# Adelaide                          0.00
# Jagajaga                         -0.15
# Hotham                           -1.93
# Corio                            -0.51
# Maribyrnong                      -0.08
# Kingsford Smith                  -2.04
# Calwell                           0.23
# Lalor                            -0.04
# Spence                            0.00
# Bean                              0.00
# Ballarat                          0.00
# Burt                             -1.95
# Macnamara                         1.15
# Franklin                          0.00
# Chifley                           0.41
# Perth                            -0.50
# Blaxland                         -0.49
# Cunningham                        0.70
# Scullin                          -0.07
# Fenner                            0.00
# Watson                            0.62
# Kingston                          0.00
# Fraser                            0.36
# Fremantle                         0.02
# Clark                             0.00
# Brand                             0.68
# Newcastle                        -0.17
# Melbourne                        -6.05
# Canberra                          0.00
# Sydney                           -0.29
# Cooper                            0.58
# Grayndler                        -1.49
# Wills                             2.59

# %%
print(pendulum.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Labor TPP</th>
#       <th>Approximated</th>
#       <th>State</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Wills</th>
#       <td>78.36</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Grayndler</th>
#       <td>77.36</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Cooper</th>
#       <td>76.04</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Sydney</th>
#       <td>75.28</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Canberra</th>
#       <td>72.46</td>
#       <td>False</td>
#       <td>ACT</td>
#     </tr>
#     <tr>
#       <th>Melbourne</th>
#       <td>71.86</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Newcastle</th>
#       <td>67.81</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Brand</th>
#       <td>67.39</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Clark</th>
#       <td>67.24</td>
#       <td>False</td>
#       <td>TAS</td>
#     </tr>
#     <tr>
#       <th>Fremantle</th>
#       <td>66.91</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Fraser</th>
#       <td>66.86</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Kingston</th>
#       <td>66.35</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Watson</th>
#       <td>65.72</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Fenner</th>
#       <td>65.69</td>
#       <td>False</td>
#       <td>ACT</td>
#     </tr>
#     <tr>
#       <th>Scullin</th>
#       <td>65.51</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Cunningham</th>
#       <td>65.40</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Blaxland</th>
#       <td>64.45</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Perth</th>
#       <td>64.30</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Chifley</th>
#       <td>63.88</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Franklin</th>
#       <td>63.70</td>
#       <td>False</td>
#       <td>TAS</td>
#     </tr>
#     <tr>
#       <th>Macnamara</th>
#       <td>63.40</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Burt</th>
#       <td>63.26</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Ballarat</th>
#       <td>62.97</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Bean</th>
#       <td>62.95</td>
#       <td>False</td>
#       <td>ACT</td>
#     </tr>
#     <tr>
#       <th>Spence</th>
#       <td>62.90</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Lalor</th>
#       <td>62.78</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Calwell</th>
#       <td>62.62</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Kingsford Smith</th>
#       <td>62.46</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Maribyrnong</th>
#       <td>62.37</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Corio</th>
#       <td>62.33</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Hotham</th>
#       <td>62.32</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Jagajaga</th>
#       <td>62.20</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Adelaide</th>
#       <td>61.91</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Barton</th>
#       <td>61.71</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Oxley</th>
#       <td>61.59</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Griffith</th>
#       <td>61.07</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Hasluck</th>
#       <td>61.04</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Bendigo</th>
#       <td>61.03</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Makin</th>
#       <td>60.80</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Mcmahon</th>
#       <td>60.67</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Lilley</th>
#       <td>60.54</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Gellibrand</th>
#       <td>60.51</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Macarthur</th>
#       <td>60.36</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Gorton</th>
#       <td>59.93</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Swan</th>
#       <td>59.81</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Isaacs</th>
#       <td>59.45</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Cowan</th>
#       <td>59.39</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Solomon</th>
#       <td>59.37</td>
#       <td>False</td>
#       <td>NT</td>
#     </tr>
#     <tr>
#       <th>Moreton</th>
#       <td>59.09</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Rankin</th>
#       <td>59.09</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Pearce</th>
#       <td>59.07</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Hindmarsh</th>
#       <td>58.95</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Richmond</th>
#       <td>58.23</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Corangamite</th>
#       <td>58.17</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Greenway</th>
#       <td>58.06</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Whitlam</th>
#       <td>57.94</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Dunkley</th>
#       <td>57.69</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Hawke</th>
#       <td>57.61</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Eden-monaro</th>
#       <td>57.30</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Dobell</th>
#       <td>56.86</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Holt</th>
#       <td>56.72</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Macquarie</th>
#       <td>56.18</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Fowler</th>
#       <td>56.04</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Shortland</th>
#       <td>55.98</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Bruce</th>
#       <td>55.43</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Blair</th>
#       <td>55.23</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Reid</th>
#       <td>55.14</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Werriwa</th>
#       <td>55.06</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Hunter</th>
#       <td>54.72</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Brisbane</th>
#       <td>54.40</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Parramatta</th>
#       <td>53.54</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Mcewen</th>
#       <td>53.54</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Boothby</th>
#       <td>53.28</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Chisholm</th>
#       <td>53.06</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Tangney</th>
#       <td>52.90</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Paterson</th>
#       <td>52.68</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Ryan</th>
#       <td>52.42</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Bullwinkel</th>
#       <td>52.33</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Robertson</th>
#       <td>51.97</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Mayo</th>
#       <td>51.59</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Lingiari</th>
#       <td>50.95</td>
#       <td>False</td>
#       <td>NT</td>
#     </tr>
#     <tr>
#       <th>Lyons</th>
#       <td>50.92</td>
#       <td>False</td>
#       <td>TAS</td>
#     </tr>
#     <tr>
#       <th>Menzies</th>
#       <td>50.82</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Gilmore</th>
#       <td>50.16</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Deakin</th>
#       <td>50.01</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Bennelong</th>
#       <td>49.67</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Warringah</th>
#       <td>49.59</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Sturt</th>
#       <td>49.55</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Moore</th>
#       <td>49.16</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Canning</th>
#       <td>48.97</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Bass</th>
#       <td>48.57</td>
#       <td>False</td>
#       <td>TAS</td>
#     </tr>
#     <tr>
#       <th>Casey</th>
#       <td>48.32</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Dickson</th>
#       <td>48.30</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Wentworth</th>
#       <td>48.28</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Aston</th>
#       <td>47.57</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Monash</th>
#       <td>47.10</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Longman</th>
#       <td>46.92</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Goldstein</th>
#       <td>46.76</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Bonner</th>
#       <td>46.59</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Leichhardt</th>
#       <td>46.56</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Flynn</th>
#       <td>46.18</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Banks</th>
#       <td>46.17</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Hughes</th>
#       <td>46.09</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Forrest</th>
#       <td>45.97</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Forde</th>
#       <td>45.77</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Petrie</th>
#       <td>45.56</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Durack</th>
#       <td>44.99</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Kooyong</th>
#       <td>44.96</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Indi</th>
#       <td>44.74</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Bowman</th>
#       <td>44.49</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Curtin</th>
#       <td>44.41</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Lindsay</th>
#       <td>44.02</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Bradfield</th>
#       <td>43.60</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Capricornia</th>
#       <td>43.41</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Flinders</th>
#       <td>43.37</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>O'connor</th>
#       <td>43.34</td>
#       <td>True</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>Berowra</th>
#       <td>42.63</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Mackellar</th>
#       <td>42.15</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Hume</th>
#       <td>42.07</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Braddon</th>
#       <td>41.97</td>
#       <td>False</td>
#       <td>TAS</td>
#     </tr>
#     <tr>
#       <th>La Trobe</th>
#       <td>41.71</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Fisher</th>
#       <td>41.33</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Wannon</th>
#       <td>41.32</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Fairfax</th>
#       <td>41.05</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>McPherson</th>
#       <td>40.66</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Cowper</th>
#       <td>40.50</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Mitchell</th>
#       <td>40.01</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Grey</th>
#       <td>39.93</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Hinkler</th>
#       <td>39.93</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Kennedy</th>
#       <td>39.84</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Riverina</th>
#       <td>39.83</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Dawson</th>
#       <td>39.58</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Fadden</th>
#       <td>39.37</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Page</th>
#       <td>39.32</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Wright</th>
#       <td>39.11</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Moncrieff</th>
#       <td>38.81</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Wide Bay</th>
#       <td>38.66</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Cook</th>
#       <td>38.49</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Herbert</th>
#       <td>38.23</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Lyne</th>
#       <td>36.20</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Groom</th>
#       <td>35.83</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#     <tr>
#       <th>Calare</th>
#       <td>34.55</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>New England</th>
#       <td>34.13</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Nicholls</th>
#       <td>33.83</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Farrer</th>
#       <td>33.65</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Barker</th>
#       <td>33.38</td>
#       <td>False</td>
#       <td>SA</td>
#     </tr>
#     <tr>
#       <th>Parkes</th>
#       <td>32.18</td>
#       <td>True</td>
#       <td>NSW</td>
#     </tr>
#     <tr>
#       <th>Mallee</th>
#       <td>31.01</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Gippsland</th>
#       <td>29.43</td>
#       <td>True</td>
#       <td>VIC</td>
#     </tr>
#     <tr>
#       <th>Maranoa</th>
#       <td>27.88</td>
#       <td>False</td>
#       <td>QLD</td>
#     </tr>
#   </tbody>
# </table>
